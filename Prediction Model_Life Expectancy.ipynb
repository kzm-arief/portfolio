# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("life_expectancy.csv")
df.head()
# Out:
#        country  year      status  life_expectancy   adult_mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    polio  total_expenditure  diphtheria   hiv_aids         gdp  population  \
# ...

# %%
df['status'].replace(to_replace=['Developing', 'Developed'], value=[0, 1], inplace=True)
df.head()
# Out:
#        country  year  status  life_expectancy   adult_mortality  \
# 0  Afghanistan  2015       0              65.0            263.0
# 1  Afghanistan  2014       0              59.9            271.0
# 2  Afghanistan  2013       0              59.9            268.0
# 3  Afghanistan  2012       0              59.5            272.0
# 4  Afghanistan  2011       0              59.2            275.0
#
#    infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    polio  total_expenditure  diphtheria   hiv_aids         gdp  population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          2938 non-null   object
#  1   year                             2938 non-null   int64
#  2   status                           2938 non-null   int64
#  3   life_expectancy                  2928 non-null   float64
#  4   adult_mortality                  2928 non-null   float64
#  5   infant_deaths                    2938 non-null   int64
#  6   alcohol                          2744 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   hepatitis_b                      2385 non-null   float64
#  9   measles                          2938 non-null   int64
#  10  bmi                              2904 non-null   float64
#  11  under_five_deaths                2938 non-null   int64
# ...

# %% [markdown]
# # **1 Descriptive Statistics**

# %%
#Overall Descriptive Statistics
df.describe()
# Out:
#               year       status  life_expectancy   adult_mortality  \
# count  2938.000000  2938.000000       2928.000000      2928.000000
# mean   2007.518720     0.174268         69.224932       164.796448
# std       4.613841     0.379405          9.523867       124.292079
# min    2000.000000     0.000000         36.300000         1.000000
# 25%    2004.000000     0.000000         63.100000        74.000000
# 50%    2008.000000     0.000000         72.100000       144.000000
# 75%    2012.000000     0.000000         75.700000       228.000000
# max    2015.000000     1.000000         89.000000       723.000000
#
#        infant_deaths      alcohol  percentage_expenditure  hepatitis_b  \
# count    2938.000000  2744.000000             2938.000000  2385.000000
# mean       30.303948     4.602861              738.251295    80.940461
# std       117.926501     4.052413             1987.914858    25.070016
# min         0.000000     0.010000                0.000000     1.000000
# ...

# %%
#Grouping Dataset based on Country
dfc = df.groupby("country")

#Show the first data of each country
dfc.first()
# Out:
#                                     year  status  life_expectancy   \
# country
# Afghanistan                         2015       0              65.0
# Albania                             2015       0              77.8
# Algeria                             2015       0              75.6
# Angola                              2015       0              52.4
# Antigua and Barbuda                 2015       0              76.4
# ...                                  ...     ...               ...
# Venezuela (Bolivarian Republic of)  2015       0              74.1
# Viet Nam                            2015       0              76.0
# Yemen                               2015       0              65.7
# Zambia                              2015       0              61.8
# Zimbabwe                            2015       0              67.0
#
#                                     adult_mortality  infant_deaths  alcohol  \
# country
# ...

# %%
df_c = df.groupby(['country']).describe()
df_c
# Out:
#                                     year                                     \
#                                    count    mean       std     min      25%
# country
# Afghanistan                         16.0  2007.5  4.760952  2000.0  2003.75
# Albania                             16.0  2007.5  4.760952  2000.0  2003.75
# Algeria                             16.0  2007.5  4.760952  2000.0  2003.75
# Angola                              16.0  2007.5  4.760952  2000.0  2003.75
# Antigua and Barbuda                 16.0  2007.5  4.760952  2000.0  2003.75
# ...                                  ...     ...       ...     ...      ...
# Venezuela (Bolivarian Republic of)  16.0  2007.5  4.760952  2000.0  2003.75
# Viet Nam                            16.0  2007.5  4.760952  2000.0  2003.75
# Yemen                               16.0  2007.5  4.760952  2000.0  2003.75
# Zambia                              16.0  2007.5  4.760952  2000.0  2003.75
# ...

# %%
df_c.to_csv("df_country.csv", index=True)

# %%
dfs = df.groupby(['status'])['country'].describe()
dfs
# Out:
#        count unique          top freq
# status
# 0       2426    161  Afghanistan   16
# 1        512     32    Australia   16

# %% [markdown]
# # **2 Data Pre-Processing**

# %%
df_drop = df.dropna()
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          1649 non-null   object
#  1   year                             1649 non-null   int64
#  2   status                           1649 non-null   int64
#  3   life_expectancy                  1649 non-null   float64
#  4   adult_mortality                  1649 non-null   float64
#  5   infant_deaths                    1649 non-null   int64
#  6   alcohol                          1649 non-null   float64
#  7   percentage_expenditure           1649 non-null   float64
#  8   hepatitis_b                      1649 non-null   float64
#  9   measles                          1649 non-null   int64
#  10  bmi                              1649 non-null   float64
#  11  under_five_deaths                1649 non-null   int64
# ...

# %%
datastr = df[df.columns[:3]]
datastr
# Out:
#           country  year  status
# 0     Afghanistan  2015       0
# 1     Afghanistan  2014       0
# 2     Afghanistan  2013       0
# 3     Afghanistan  2012       0
# 4     Afghanistan  2011       0
# ...           ...   ...     ...
# 2933     Zimbabwe  2004       0
# 2934     Zimbabwe  2003       0
# 2935     Zimbabwe  2002       0
# 2936     Zimbabwe  2001       0
# 2937     Zimbabwe  2000       0
#
# [2938 rows x 3 columns]

# %%
datastr['status'].replace(to_replace=['Developing', 'Developed'], value=[0, 1], inplace=True)
datastr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#        country  year  status
# 0  Afghanistan  2015       0
# 1  Afghanistan  2014       0
# 2  Afghanistan  2013       0
# 3  Afghanistan  2012       0
# 4  Afghanistan  2011       0

# %%
datastr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  2938 non-null   object
#  1   year     2938 non-null   int64
#  2   status   2938 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 69.0+ KB

# %%
datanum = df[df.columns[3:]].to_numpy()
datanum
# Out:
# array([[6.50e+01, 2.63e+02, 6.20e+01, ..., 1.73e+01, 4.79e-01, 1.01e+01],
#        [5.99e+01, 2.71e+02, 6.40e+01, ..., 1.75e+01, 4.76e-01, 1.00e+01],
#        [5.99e+01, 2.68e+02, 6.60e+01, ..., 1.77e+01, 4.70e-01, 9.90e+00],
#        ...,
#        [4.48e+01, 7.30e+01, 2.50e+01, ..., 1.30e+00, 4.27e-01, 1.00e+01],
#        [4.53e+01, 6.86e+02, 2.50e+01, ..., 1.70e+00, 4.27e-01, 9.80e+00],
#        [4.60e+01, 6.65e+02, 2.40e+01, ..., 1.12e+01, 4.34e-01, 9.80e+00]])

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df_knn = imputer.fit_transform(datanum)
df_knn
# Out:
# array([[6.50e+01, 2.63e+02, 6.20e+01, ..., 1.73e+01, 4.79e-01, 1.01e+01],
#        [5.99e+01, 2.71e+02, 6.40e+01, ..., 1.75e+01, 4.76e-01, 1.00e+01],
#        [5.99e+01, 2.68e+02, 6.60e+01, ..., 1.77e+01, 4.70e-01, 9.90e+00],
#        ...,
#        [4.48e+01, 7.30e+01, 2.50e+01, ..., 1.30e+00, 4.27e-01, 1.00e+01],
#        [4.53e+01, 6.86e+02, 2.50e+01, ..., 1.70e+00, 4.27e-01, 9.80e+00],
#        [4.60e+01, 6.65e+02, 2.40e+01, ..., 1.12e+01, 4.34e-01, 9.80e+00]])

# %%
df_knn2 = pd.DataFrame(df_knn, columns = ['life_expectancy',	'adult_mortality',	'infant_deaths',	'alcohol',	'percentage_expenditure',	'hepatitis_b',	'measles', 'bmi', 'under_five_death',	'polio',	'total_expenditure',	'diphtheria',	'hiv_aids',	'gdp',	'population',	',thinness_1_19_years',	'thinness_5_9_years',	'income_composition_of_resources',	'schooling'])
df_knn2
# Out:
#       life_expectancy  adult_mortality  infant_deaths  alcohol  \
# 0                65.0            263.0           62.0     0.01
# 1                59.9            271.0           64.0     0.01
# 2                59.9            268.0           66.0     0.01
# 3                59.5            272.0           69.0     0.01
# 4                59.2            275.0           71.0     0.01
# ...               ...              ...            ...      ...
# 2933             44.3            723.0           27.0     4.36
# 2934             44.5            715.0           26.0     4.06
# 2935             44.8             73.0           25.0     4.43
# 2936             45.3            686.0           25.0     1.72
# 2937             46.0            665.0           24.0     1.68
#
#       percentage_expenditure  hepatitis_b  measles   bmi  under_five_death  \
# 0                  71.279624         65.0   1154.0  19.1              83.0
# ...

# %%
df_clean = pd.merge(datastr, df_knn2, left_index=True, right_index=True)
df_clean
# Out:
#           country  year  status  life_expectancy  adult_mortality  \
# 0     Afghanistan  2015       0             65.0            263.0
# 1     Afghanistan  2014       0             59.9            271.0
# 2     Afghanistan  2013       0             59.9            268.0
# 3     Afghanistan  2012       0             59.5            272.0
# 4     Afghanistan  2011       0             59.2            275.0
# ...           ...   ...     ...              ...              ...
# 2933     Zimbabwe  2004       0             44.3            723.0
# 2934     Zimbabwe  2003       0             44.5            715.0
# 2935     Zimbabwe  2002       0             44.8             73.0
# 2936     Zimbabwe  2001       0             45.3            686.0
# 2937     Zimbabwe  2000       0             46.0            665.0
#
#       infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles  \
# 0              62.0     0.01               71.279624         65.0   1154.0
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          2938 non-null   object
#  1   year                             2938 non-null   int64
#  2   status                           2938 non-null   int64
#  3   life_expectancy                  2938 non-null   float64
#  4   adult_mortality                  2938 non-null   float64
#  5   infant_deaths                    2938 non-null   float64
#  6   alcohol                          2938 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   hepatitis_b                      2938 non-null   float64
#  9   measles                          2938 non-null   float64
#  10  bmi                              2938 non-null   float64
#  11  under_five_death                 2938 non-null   float64
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse

# %%
#Correllation for Raw Data

corr0 = df.corr(method='kendall')
plt.figure(figsize=(20,16))
sns.heatmap(corr0, annot=True)
df.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy ', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles ', 'bmi', 'under_five_deaths ', 'polio', 'total_expenditure',
#        'diphtheria ', 'hiv_aids', 'gdp', 'population', ' thinness_1_19_years',
#        ' thinness_5_9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
 #Correllation for Cleaned Data

corr1 = df_clean.corr(method='kendall')
plt.figure(figsize=(20,16))
sns.heatmap(corr1, annot=True)
df_clean.columns
# Out:
# Index(['country', 'year', 'status', 'life_expectancy', 'adult_mortality',
#        'infant_deaths', 'alcohol', 'percentage_expenditure', 'hepatitis_b',
#        'measles', 'bmi', 'under_five_death', 'polio', 'total_expenditure',
#        'diphtheria', 'hiv_aids', 'gdp', 'population', ',thinness_1_19_years',
#        'thinness_5_9_years', 'income_composition_of_resources', 'schooling'],
#       dtype='object')

# %%
corr0.head()
# Out:
#                       year    status  life_expectancy   adult_mortality  \
# year              1.000000 -0.001570          0.110917        -0.037146
# status           -0.001570  1.000000          0.446569        -0.294255
# life_expectancy   0.110917  0.446569          1.000000        -0.558344
# adult_mortality  -0.037146 -0.294255         -0.558344         1.000000
# infant_deaths    -0.037978 -0.330398         -0.428247         0.279324
#
#                   infant_deaths   alcohol  percentage_expenditure  \
# year                  -0.037978 -0.069147               -0.029752
# status                -0.330398  0.444776                0.257069
# life_expectancy       -0.428247  0.295211                0.310871
# adult_mortality        0.279324 -0.143264               -0.207935
# infant_deaths          1.000000 -0.275734               -0.260344
#
#                   hepatitis_b  measles        bmi  ...     polio  \
# year                 0.069983 -0.068226  0.105347  ...  0.077492
# ...

# %%
corr1.head()
# Out:
#                      year    status  life_expectancy  adult_mortality  \
# year             1.000000 -0.001570         0.111363        -0.037400
# status          -0.001570  1.000000         0.445793        -0.293800
# life_expectancy  0.111363  0.445793         1.000000        -0.558391
# adult_mortality -0.037400 -0.293800        -0.558391         1.000000
# infant_deaths   -0.037978 -0.330398        -0.427561         0.278701
#
#                  infant_deaths   alcohol  percentage_expenditure  hepatitis_b  \
# year                 -0.037978 -0.049324               -0.029752     0.115229
# status               -0.330398  0.433359                0.257069     0.160065
# life_expectancy      -0.427561  0.295870                0.308563     0.283289
# adult_mortality       0.278701 -0.147020               -0.206427    -0.174504
# infant_deaths         1.000000 -0.279294               -0.260344    -0.292362
#
#                   measles       bmi  ...     polio  total_expenditure  \
# ...

# %%
corr0.to_csv("corr0.csv", index=True)
corr1.to_csv("corr1.csv", index=True)

# %% [markdown]
# # **4. Predictive Model**

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          2938 non-null   object
#  1   year                             2938 non-null   int64
#  2   status                           2938 non-null   int64
#  3   life_expectancy                  2938 non-null   float64
#  4   adult_mortality                  2938 non-null   float64
#  5   infant_deaths                    2938 non-null   float64
#  6   alcohol                          2938 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   hepatitis_b                      2938 non-null   float64
#  9   measles                          2938 non-null   float64
#  10  bmi                              2938 non-null   float64
#  11  under_five_death                 2938 non-null   float64
# ...

# %%
target = df_clean['life_expectancy'].to_numpy()
target
# Out:
# array([65. , 59.9, 59.9, ..., 44.8, 45.3, 46. ])

# %%
factor = df_clean.drop(columns=["country", "life_expectancy"]).to_numpy()
factor
# Out:
# array([[2.015e+03, 0.000e+00, 2.630e+02, ..., 1.730e+01, 4.790e-01,
#         1.010e+01],
#        [2.014e+03, 0.000e+00, 2.710e+02, ..., 1.750e+01, 4.760e-01,
#         1.000e+01],
#        [2.013e+03, 0.000e+00, 2.680e+02, ..., 1.770e+01, 4.700e-01,
#         9.900e+00],
#        ...,
#        [2.002e+03, 0.000e+00, 7.300e+01, ..., 1.300e+00, 4.270e-01,
#         1.000e+01],
#        [2.001e+03, 0.000e+00, 6.860e+02, ..., 1.700e+00, 4.270e-01,
#         9.800e+00],
#        [2.000e+03, 0.000e+00, 6.650e+02, ..., 1.120e+01, 4.340e-01,
#         9.800e+00]])

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaler.fit(factor)
factor_scaled = scaler.transform(factor)
factor_scaled
# Out:
# array([[1.        , 0.        , 0.36288089, ..., 0.60350877, 0.50527426,
#         0.48792271],
#        [0.93333333, 0.        , 0.37396122, ..., 0.61052632, 0.5021097 ,
#         0.48309179],
#        [0.86666667, 0.        , 0.36980609, ..., 0.61754386, 0.49578059,
#         0.47826087],
#        ...,
#        [0.13333333, 0.        , 0.09972299, ..., 0.04210526, 0.45042194,
#         0.48309179],
#        [0.06666667, 0.        , 0.94875346, ..., 0.05614035, 0.45042194,
#         0.47342995],
#        [0.        , 0.        , 0.91966759, ..., 0.38947368, 0.45780591,
#         0.47342995]])

# %% [markdown]
# Linear Regression

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

reg = LinearRegression()

kf = KFold(n_splits=5, shuffle=False)
print(kf)

i=1
kf.get_n_splits(factor)
for train_index, test_index in kf.split(factor):
  X_train, X_test = factor[train_index], factor[test_index]
  y_train, y_test = target[train_index], target[test_index]
  reg = reg.fit(X_train, y_train)
  predict_train = reg.predict(X_train)
  predict_test = reg.predict(X_test)
  print("fold :", i)
  #print("Coef:", reg.coef_)
  print("R-squared training: " , r2_score (y_train, predict_train))
  print("R-squared testing: " , r2_score (y_test, predict_test))
  print("MSE training: " , mean_squared_error (y_train, predict_train))
  print("MSE testing: " , mean_squared_error (y_train, predict_train))
  print("MAPE training: " , mean_absolute_percentage_error (y_train, predict_train))
  print("MAPE testing: " , mean_absolute_percentage_error (y_train, predict_train))
  i+=1
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)
# fold : 1
# R-squared training:  0.8297095915795447
# R-squared testing:  0.8247000927005765
# MSE training:  14.676675291305006
# MSE testing:  14.676675291305006
# MAPE training:  0.04344849564095335
# MAPE testing:  0.04344849564095335
# fold : 2
# R-squared training:  0.8309783230063814
# R-squared testing:  0.8203640089125028
# MSE training:  15.618937940467713
# MSE testing:  15.618937940467713
# MAPE training:  0.0444794978698706
# MAPE testing:  0.0444794978698706
# fold : 3
# R-squared training:  0.8339659364783175
# R-squared testing:  0.8072031378697228
# MSE training:  15.444655929776768
# MSE testing:  15.444655929776768
# MAPE training:  0.04505956224795867
# MAPE testing:  0.04505956224795867
# fold : 4
# R-squared training:  0.8403417930682369
# R-squared testing:  0.7398484602995083
# MSE training:  14.591897504598899
# MSE testing:  14.591897504598899
# MAPE training:  0.044360435843425784
# ...

# %%
reg = LinearRegression().fit(factor, target)
reg.coef_
# Out:
# array([-2.26171051e-02,  1.28478290e+00, -1.78734397e-02,  9.90115434e-02,
#         3.58282153e-02,  4.32559521e-06, -9.52167037e-03, -1.50231341e-05,
#         3.77377182e-02, -7.36379079e-02,  2.64416026e-02,  7.79419055e-02,
#         3.38471121e-02, -4.87543613e-01,  4.86858952e-05, -1.67186325e-09,
#        -6.70454515e-02, -8.20025139e-03,  6.51379727e+00,  7.39732082e-01])

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

reg_scaled = LinearRegression()

kf = KFold(n_splits=5, shuffle=False)
print(kf)

i=1
kf.get_n_splits(factor_scaled)
for train_index, test_index in kf.split(factor_scaled):
  X_train, X_test = factor_scaled[train_index], factor_scaled[test_index]
  y_train, y_test = target[train_index], target[test_index]
  reg_scaled = reg_scaled.fit(X_train, y_train)
  predict_train = reg_scaled.predict(X_train)
  predict_test = reg_scaled.predict(X_test)
  print("fold :", i)
  #print("Coef:", reg.coef_)
  print("R-squared training: " , r2_score (y_train, predict_train))
  print("R-squared testing: " , r2_score (y_test, predict_test))
  print("MSE training: " , mean_squared_error (y_train, predict_train))
  print("MSE testing: " , mean_squared_error (y_train, predict_train))
  print("MAPE training: " , mean_absolute_percentage_error (y_train, predict_train))
  print("MAPE testing: " , mean_absolute_percentage_error (y_train, predict_train))
  i+=1
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)
# fold : 1
# R-squared training:  0.8297095915795447
# R-squared testing:  0.8247000927807732
# MSE training:  14.676675291305006
# MSE testing:  14.676675291305006
# MAPE training:  0.04344849564868083
# MAPE testing:  0.04344849564868083
# fold : 2
# R-squared training:  0.8309783230063814
# R-squared testing:  0.8203640089708322
# MSE training:  15.618937940467713
# MSE testing:  15.618937940467713
# MAPE training:  0.04447949787230258
# MAPE testing:  0.04447949787230258
# fold : 3
# R-squared training:  0.8339659364783175
# R-squared testing:  0.8072031383170306
# MSE training:  15.444655929776768
# MSE testing:  15.444655929776768
# MAPE training:  0.04505956224908575
# MAPE testing:  0.04505956224908575
# fold : 4
# R-squared training:  0.8403417930682368
# R-squared testing:  0.7398484604118664
# MSE training:  14.591897504598903
# MSE testing:  14.591897504598903
# MAPE training:  0.04436043584222928
# ...

# %%
reg_scaled = LinearRegression().fit(factor_scaled, target)
reg_scaled.coef_
# Out:
# array([-3.39256576e-01,  1.28478290e+00, -1.29046235e+01,  1.78220778e+02,
#         6.39891926e-01,  8.42622132e-02, -9.33123697e-01, -3.18765367e+00,
#         3.25676508e+00, -1.84094770e+02,  2.53839385e+00,  1.34293903e+00,
#         3.28316987e+00, -2.46209525e+01,  5.80194976e+00, -2.16315604e+00,
#        -1.85045446e+00, -2.33707165e-01,  6.17507981e+00,  1.53124541e+01])

# %% [markdown]
# Random Forest Regressor

# %%
# grid search
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

rf_reg = RandomForestRegressor()
params = {"n_estimators": [5, 10, 20, 50, 100, 200, 300],
          "max_depth": [None, 2, 5, 7, 10]
          }

# randomsearch = RandomizedSearchCV(rf_reg, params, scoring='neg_mean_squared_error')
randomsearch = GridSearchCV(rf_reg, params, scoring='neg_mean_squared_error')
randomsearch.fit(factor, target)

best_rf_reg = randomsearch.best_estimator_
print (randomsearch.best_params_)
# Out:
# {'max_depth': None, 'n_estimators': 300}

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=300, max_depth=None)

kf = KFold(n_splits=5, shuffle=False)
print(kf)

i=1
kf.get_n_splits(factor)
for train_index, test_index in kf.split(factor):
  X_train, X_test = factor[train_index], factor[test_index]
  y_train, y_test = target[train_index], target[test_index]
  rf = rf.fit(X_train, y_train)
  predict_train = rf.predict(X_train)
  predict_test = rf.predict(X_test)
  print("fold :", i)
  #print("Coef:", rf.coef_)
  print("R-squared training: " , r2_score (y_train, predict_train))
  print("R-squared testing: " , r2_score (y_test, predict_test))
  print("MSE training: " , mean_squared_error (y_train, predict_train))
  print("MSE testing: " , mean_squared_error (y_train, predict_train))
  print("MAPE training: " , mean_absolute_percentage_error (y_train, predict_train))
  print("MAPE testing: " , mean_absolute_percentage_error (y_train, predict_train))
  i+=1
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)
# fold : 1
# R-squared training:  0.9945980863588457
# R-squared testing:  0.9451981955268274
# MSE training:  0.4655701586382975
# MSE testing:  0.4655701586382975
# MAPE training:  0.006212539369881023
# MAPE testing:  0.006212539369881023
# fold : 2
# R-squared training:  0.9953725447648399
# R-squared testing:  0.8810467061942785
# MSE training:  0.42761341282269605
# MSE testing:  0.42761341282269605
# MAPE training:  0.005961970763022241
# MAPE testing:  0.005961970763022241
# fold : 3
# R-squared training:  0.995218220408958
# R-squared testing:  0.9197091129980244
# MSE training:  0.4448059569777799
# MSE testing:  0.4448059569777799
# MAPE training:  0.006169816194237012
# MAPE testing:  0.006169816194237012
# fold : 4
# R-squared training:  0.9955667786754634
# R-squared testing:  0.9171563570437182
# MSE training:  0.40517247704333975
# MSE testing:  0.40517247704333975
# MAPE training:  0.0058920521192027285
# ...

# %%
rf.feature_importances_
# Out:
# array([6.04814648e-03, 2.07158410e-04, 1.08456460e-01, 3.90733772e-03,
#        6.25354742e-03, 3.04107995e-03, 3.15752993e-03, 2.96375804e-03,
#        1.09300308e-02, 6.27081529e-03, 4.03398739e-03, 6.13725494e-03,
#        4.33357316e-03, 3.79456532e-01, 3.96807485e-03, 3.42968327e-03,
#        5.17735967e-03, 1.01967961e-02, 4.18281196e-01, 1.37496790e-02])

# %%
from sklearn.ensemble import RandomForestRegressor

rf_scaled = RandomForestRegressor(n_estimators=300, max_depth=None)

kf = KFold(n_splits=5, shuffle=False)
print(kf)

i=1
kf.get_n_splits(factor_scaled)
for train_index, test_index in kf.split(factor_scaled):
  X_train, X_test = factor_scaled[train_index], factor_scaled[test_index]
  y_train, y_test = target[train_index], target[test_index]
  rf_scaled = rf_scaled.fit(X_train, y_train)
  predict_train = rf_scaled.predict(X_train)
  predict_test = rf_scaled.predict(X_test)
  print("fold :", i)
  #print("Coef:", rf.coef_)
  print("R-squared training: " , r2_score (y_train, predict_train))
  print("R-squared testing: " , r2_score (y_test, predict_test))
  print("MSE training: " , mean_squared_error (y_train, predict_train))
  print("MSE testing: " , mean_squared_error (y_train, predict_train))
  print("MAPE training: " , mean_absolute_percentage_error (y_train, predict_train))
  print("MAPE testing: " , mean_absolute_percentage_error (y_train, predict_train))
  i+=1
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)
# fold : 1
# R-squared training:  0.994504540298612
# R-squared testing:  0.9452051728078171
# MSE training:  0.4736325337512999
# MSE testing:  0.4736325337512999
# MAPE training:  0.006263407859555174
# MAPE testing:  0.006263407859555174
# fold : 2
# R-squared training:  0.9955374201890668
# R-squared testing:  0.88401138670447
# MSE training:  0.4123776213862896
# MSE testing:  0.4123776213862896
# MAPE training:  0.005834841673734262
# MAPE testing:  0.005834841673734262
# fold : 3
# R-squared training:  0.9949345371482895
# R-squared testing:  0.9194076184732941
# MSE training:  0.47119445980142033
# MSE testing:  0.47119445980142033
# MAPE training:  0.006252852523217376
# MAPE testing:  0.006252852523217376
# fold : 4
# R-squared training:  0.9953844378815234
# R-squared testing:  0.9171437579397749
# MSE training:  0.42183744044992805
# MSE testing:  0.42183744044992805
# MAPE training:  0.005991821255450584
# ...

# %% [markdown]
# Lasso Regression

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha = 0.3)

from sklearn.model_selection import KFold
from sklearn.metrics import r2_score

kf = KFold(n_splits=5, shuffle=False)
print(kf)

i=1
kf.get_n_splits(factor)
for train_index, test_index in kf.split(factor):
  X_train, X_test = factor[train_index], factor[test_index]
  y_train, y_test = target[train_index], target[test_index]
  reg = lasso_reg.fit(X_train, y_train)
  predict_train = reg.predict(X_train)
  predict_test = reg.predict(X_test)
  print("fold :", i)
  #print("Coef:", reg.coef_)
  print("R-squared training: " , r2_score (y_train, predict_train))
  print("R-squared testing: " , r2_score (y_test, predict_test))
  print("MSE training: " , mean_squared_error (y_train, predict_train))
  print("MSE testing: " , mean_squared_error (y_train, predict_train))
  print("MAPE training: " , mean_absolute_percentage_error (y_train, predict_train))
  print("MAPE testing: " , mean_absolute_percentage_error (y_train, predict_train))
  i+=1
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)
# fold : 1
# R-squared training:  0.8170625403157148
# R-squared testing:  0.8305081640014442
# MSE training:  15.766675993713465
# MSE testing:  15.766675993713465
# MAPE training:  0.04486712981485453
# MAPE testing:  0.04486712981485453
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.976e+04, tolerance: 2.025e+01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.005e+04, tolerance: 2.172e+01
# ...

# %% [markdown]
# Decision Tree Regression

# %%
DTree = DecisionTreeRegressor(random_state=0, min_samples_leaf=.000001)

kf = KFold(n_splits=5, shuffle=False)
print(kf)

i=1
kf.get_n_splits(factor)
for train_index, test_index in kf.split(factor):
  X_train, X_test = factor[train_index], factor[test_index]
  y_train, y_test = target[train_index], target[test_index]
  reg = DTree.fit(X_train,y_train)
  predict_train = reg.predict(X_train)
  predict_test = reg.predict(X_test)
  print("fold :", i)
  #print("Coef:", reg.coef_)
  print("R-squared training: " , r2_score (y_train, predict_train))
  print("R-squared testing: " , r2_score (y_test, predict_test))
  print("MSE training: " , mean_squared_error (y_train, predict_train))
  print("MSE testing: " , mean_squared_error (y_train, predict_train))
  print("MAPE training: " , mean_absolute_percentage_error (y_train, predict_train))
  print("MAPE testing: " , mean_absolute_percentage_error (y_train, predict_train))
  i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-6944d22a1a5c> in <module>()
# ----> 1 DTree = DecisionTreeRegressor(random_state=0, min_samples_leaf=.000001)
#       2
#       3 kf = KFold(n_splits=5, shuffle=False)
#       4 print(kf)
#       5
#
# NameError: name 'DecisionTreeRegressor' is not defined

# %% [markdown]
# # **6. Feature Importance**

# %%
fi = pd.DataFrame(rf_scaled.feature_importances_)
fi

# %%
df_factor = df_clean.drop(columns=["country", "life_expectancy"])
df_factor = pd.DataFrame(df_factor.loc[[]]).transpose().reset_index()
df_factor

# %%
df_fi = pd.merge(df_factor, fi, left_index=True, right_index=True)
df_fi = df_fi.rename(columns={'index': 'factor', 0: 'feature_importance'})
df_fi

# %% [markdown]
# # **EDA**

# %%
df[3] = df[3].astype(float)

dd = df["status"] == 1
df_dd = df[dd]
dg = df["status"] == 0
df_dg = df[dg]

plt.hist(df_dd(columns="life_expectancy"),
		alpha=0.5, # the transaparency parameter
		label='life_expectancy')

plt.hist(df_dg[3],
		alpha=0.5, # the transaparency parameter
		label='life_expectancy')

plt.legend(loc='upper right')
plt.title('Overlapping with both alpha=0.5')
plt.show()

# %%
df_dg
