# %%
import pandas as pd
from statsmodels.multivariate.manova import MANOVA
from google.colab import files
import io

uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded['Iris.csv']))
print(df.describe())
print(df.info())

maov = MANOVA.from_formula('SepalLengthCm + SepalWidthCm + \
                            PetalLengthCm + PetalWidthCm  ~ Species', data=df)
print(maov.mv_test())
# Out:
#      <input type="file" id="files-a8fab678-be38-4a1b-93b1-b04d187d4877" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8fab678-be38-4a1b-93b1-b04d187d4877">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris (1).csv
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#                    Multivariate linear model
# ================================================================
#
# ----------------------------------------------------------------
#        Intercept         Value  Num DF  Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda  0.0170 4.0000 144.0000 2080.5278 0.0000
#          Pillai's trace  0.9830 4.0000 144.0000 2080.5278 0.0000
#  Hotelling-Lawley trace 57.7924 4.0000 144.0000 2080.5278 0.0000
#     Roy's greatest root 57.7924 4.0000 144.0000 2080.5278 0.0000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
#         Species          Value  Num DF  Den DF   F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda  0.0235 8.0000 288.0000  198.7110 0.0000
#          Pillai's trace  1.1872 8.0000 290.0000   52.9486 0.0000
#  Hotelling-Lawley trace 32.5495 8.0000 203.4024  583.4914 0.0000
#     Roy's greatest root 32.2720 4.0000 145.0000 1169.8585 0.0000
# ================================================================

# %%
import pandas as pd
from statsmodels.multivariate.manova import MANOVA
from google.colab import files
import io

uploaded = files.upload()
df2 = pd.read_csv(io.BytesIO(uploaded['StudentsPerformanceFix.csv']))
print(df2.describe())
print(df2.info())
# Out:
#      <input type="file" id="files-25f0f083-b1f6-4014-bfb9-9e353a75255a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25f0f083-b1f6-4014-bfb9-9e353a75255a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformanceFix.csv to StudentsPerformanceFix (2).csv
#              math     reading     writing
# count  373.000000  373.000000  373.000000
# mean    65.635389   69.016086   68.000000
# std     15.180669   14.822236   15.375235
# min      8.000000   24.000000   15.000000
# 25%     56.000000   59.000000   57.000000
# 50%     66.000000   70.000000   68.000000
# 75%     76.000000   79.000000   79.000000
# max    100.000000  100.000000  100.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   math     373 non-null    int64
#  1   reading  373 non-null    int64
#  2   writing  373 non-null    int64
# dtypes: int64(3)
# memory usage: 8.9 KB
# None

# %%
import numpy as np
import statsmodels.api as sm
import pylab as py
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
  
# np.random generates different random numbers
# whenever the code is executed
# Note: When you execute the same code 
# the graph look different than shown below.
  
# Random data points generated  

math = df2['math']
reading = df2['reading']
writing = df2['writing']

qqplot(math, line='s')
pyplot.show()

qqplot(reading, line='s')
pyplot.show()

qqplot(writing, line='s')
pyplot.show()
