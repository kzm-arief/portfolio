# %%
import math
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
TRAIN_DATA_PATH = '/content/sample_data/california_housing_train.csv'
TEST_DATA_PATH = '/content/sample_data/california_housing_test.csv'
TARGET_NAME = 'median_house_value'

# %%
# x_train = features, y_train = target
train_data = pd.read_csv(TRAIN_DATA_PATH)
test_data = pd.read_csv(TEST_DATA_PATH)
x_train, y_train = train_data.drop(TARGET_NAME, axis=1), train_data[TARGET_NAME]
x_test, y_test = test_data.drop(TARGET_NAME, axis=1), test_data[TARGET_NAME]

# %%
x_train
# Out:
#        longitude  latitude  ...  households  median_income
# 0        -114.31     34.19  ...       472.0         1.4936
# 1        -114.47     34.40  ...       463.0         1.8200
# 2        -114.56     33.69  ...       117.0         1.6509
# 3        -114.57     33.64  ...       226.0         3.1917
# 4        -114.57     33.57  ...       262.0         1.9250
# ...          ...       ...  ...         ...            ...
# 16995    -124.26     40.58  ...       369.0         2.3571
# 16996    -124.27     40.69  ...       465.0         2.5179
# 16997    -124.30     41.84  ...       456.0         3.0313
# 16998    -124.30     41.80  ...       478.0         1.9797
# 16999    -124.35     40.54  ...       270.0         3.0147
#
# [17000 rows x 8 columns]

# %%
def scale_datasets(x_train, x_test): 
  """
  Standard Scale test and train data
  Z - Score normalization
  """
  standard_scaler = StandardScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
hidden_units1 = 160
hidden_units2 = 480
hidden_units3 = 256
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()

# %%
# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 213/213 [==============================] - 2s 6ms/step - loss: 5.2092 - mean_squared_logarithmic_error: 5.1977 - val_loss: 0.6553 - val_mean_squared_logarithmic_error: 0.6517
# Epoch 2/10
# 213/213 [==============================] - 1s 5ms/step - loss: 0.2532 - mean_squared_logarithmic_error: 0.2533 - val_loss: 0.3663 - val_mean_squared_logarithmic_error: 0.3717
# Epoch 3/10
# 213/213 [==============================] - 1s 5ms/step - loss: 0.1905 - mean_squared_logarithmic_error: 0.1903 - val_loss: 0.2742 - val_mean_squared_logarithmic_error: 0.2822
# Epoch 4/10
# 213/213 [==============================] - 1s 5ms/step - loss: 0.1554 - mean_squared_logarithmic_error: 0.1553 - val_loss: 0.2104 - val_mean_squared_logarithmic_error: 0.2190
# Epoch 5/10
# 213/213 [==============================] - 1s 6ms/step - loss: 0.1305 - mean_squared_logarithmic_error: 0.1304 - val_loss: 0.1667 - val_mean_squared_logarithmic_error: 0.1737
# Epoch 6/10
# 213/213 [==============================] - 1s 5ms/step - loss: 0.1137 - mean_squared_logarithmic_error: 0.1137 - val_loss: 0.1410 - val_mean_squared_logarithmic_error: 0.1484
# Epoch 7/10
# 213/213 [==============================] - 1s 6ms/step - loss: 0.1065 - mean_squared_logarithmic_error: 0.1065 - val_loss: 0.1292 - val_mean_squared_logarithmic_error: 0.1356
# Epoch 8/10
# 213/213 [==============================] - 1s 5ms/step - loss: 0.1036 - mean_squared_logarithmic_error: 0.1035 - val_loss: 0.1251 - val_mean_squared_logarithmic_error: 0.1314
# Epoch 9/10
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0999 - mean_squared_logarithmic_error: 0.1000 - val_loss: 0.1183 - val_mean_squared_logarithmic_error: 0.1249
# Epoch 10/10
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0993 - mean_squared_logarithmic_error: 0.0993 - val_loss: 0.1220 - val_mean_squared_logarithmic_error: 0.1280

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mean_squared_logarithmic_error')

# %%
x_test['prediction'] = model.predict(x_test_scaled)

# %%
x_test
# Out:
#       longitude  latitude  ...  median_income     prediction
# 0       -122.05     37.37  ...         6.6085  344860.468750
# 1       -118.30     34.26  ...         3.5990  190520.437500
# 2       -117.81     33.78  ...         5.7934  260897.906250
# 3       -118.36     33.82  ...         6.1359  327819.281250
# 4       -119.67     36.33  ...         2.9375   95362.000000
# ...         ...       ...  ...            ...            ...
# 2995    -119.86     34.42  ...         1.1790  204850.500000
# 2996    -118.14     34.06  ...         3.3906  147079.968750
# 2997    -119.70     36.30  ...         2.2895  103847.179688
# 2998    -117.12     34.10  ...         3.2708  125191.695312
# 2999    -119.63     34.42  ...         8.5608  488637.437500
#
# [3000 rows x 9 columns]
